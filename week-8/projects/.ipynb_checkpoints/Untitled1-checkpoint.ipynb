# %%
# Project 1
# import the random module
import random

# create a class called Employee
class Employee():
    
    # create a parameterized constructor
    def __init__(self, name, attendance):
        self.name = name
        self.attendance = attendance
        
    def check_employee(self):
        employees = ["Mary Evans", "Eyo Ishan", "Durojaiye Dare", "Adams Ali", \
                     "Andrew Ugwu", "Stella Mankinde", "Jane Akibo", "Ago James", \
                     "Michell Taiwo", "Abraham Jones" , "Nicole Anide", "Kosi Korso", \
                     "Adele Martins", "Emmanuel Ojo", "Ajayi Fatima"]
        if name in employees:
            return True
        else:
            return False
        
    def take_attendance(self):
        if attendance == "yes" or attendance == "Yes":
            return True
        elif attendance == "no" or attendance == "No":
            return False
        else:
            print("Sorry, that is not a correct input.")
        
    def assign_task(self):
        Tasks = ["Loading", "Transporting", "Reveiwing Orders",\
                 "Customer Service", "Delivering Items"]
        global task
        task = random.choice(Tasks)
        
    def refuse_access(self):
        print("Sorry, your name is not registered a an employee")
        
print("Note: this code is case sensitive")
name = input("Input your name: ")
run = Employee(name, attendance)
run.check_employee()

if run.check_employee() == True:
    print(f"Welcome {name}!")
    attendance = input("Are you present?(yes or no): ")
    run.take_attendance()
    if run.take_attendance() == True:
        print("Attendance taken: Present")
        run.assign_task()
        print(f"Your task is {task}.")
    elif run.take_attendance() == False:
        print("Attendance taken: Absent")
        print("Since your attendance says 'Absent', no task is assigned to you.")

else:
    run.refuse_access()
    
print("Thank you.")
# Out:
# Note: this code is case sensitive
# Input your name: Mary Evans
# Welcome Mary Evans!
# Are you present?(yes or no): yes
# Attendance taken: Present
# Your task is Loading.
# Thank you.

# %%
# Create a class called Delivery
class Delivery():
    
    # parameterized constructor
    def __init__(self, location, weight):
        self.location = location
        self.weight = weight
        
    # method for if location is pau
    def pau(self):
        loc = 'Pan-atlantic university'
        if weight >= 10:
            price = 'N2,000'
        elif weight < 10:
            price = 'N1,500'
        print(f"\nThe price to deliver a package weighing {weight}kg to {loc} is {price}. Thank you.")

    # method for if location is epe
    def epe(self):
        loc = 'Epe'
        if weight >= 10:
            price = 'N5,000'
        elif weight < 10:
            price = 'N4,000'
        print(f"\nThe price to deliver a package weighing {weight}kg to {loc} is {price}. Thank you.")
        
# Code starts here
print("Yega Services")
print("\nLocations: \n1. Pan-atlantic university \n2. Epe")
location = input("\nInput the location for the delivery of your package please(1 or 2): ")

run = Delivery(location, weight)

if location == "1":
    weight = int(input("\nInput the weight of the package(In in kg): "))
    run.pau()
elif location == "2":
    weight = int(input("\nInput the weight of the package(In in kg): "))
    run.epe()
else:
    print("Sorry, not a valid input.")
# Out:
# Yega Services
#
# Locations:
# 1. Pan-atlantic university
# 2. Epe
#
# Input the location for the delivery of your package please(1 or 2): 1
#
# Input the weight of the package(In in kg): 7
#
# The price to deliver a package weighing 7kg to Pan-atlantic university is N1,500. Thank you.
